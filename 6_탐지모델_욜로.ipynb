# %% [markdown]
# # 모델 구조 + 가중치

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
data_path = './datasets1/data.yaml'
model.train(data=data_path, epochs=5, imgsz=640)
# Out:
# Ultralytics 8.3.191  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
result = model.predict('sample.png')
result
# Out:
# image 1/1 c:\githome\data_anal_DL\sample.png: 448x640 1 Paper, 2 Scissorss, 18.2ms
# Speed: 3.1ms preprocess, 18.2ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)

# %%
model = YOLO('runs\\detect\\train\\weights\\best.pt')
data_path = './datasets1/data.yaml'
metrics = model.val(data=data_path)
metrics
# Out:
# Ultralytics 8.3.191  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 597.1165.4 MB/s, size: 29.1 KB)
# val: Scanning C:\githome\data_anal_DL\datasets1\valid\labels.cache... 576 images, 238 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 576/576 532375.3it/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 36/36 11.0it/s 3.3s0.1s
#                    all        576        400      0.922      0.855      0.916      0.689
#                  Paper        132        139      0.886      0.863      0.903      0.668
#                   Rock        121        141      0.918      0.887      0.916      0.686
#               Scissors        116        120      0.961      0.815      0.928      0.712
# ...

# %%
# yolov8n.pt, best.pt의 성능비교, sample.png

# %% [markdown]
# | Metric          |        train |          val |         Δ | 비고                  |
# | --------------- | -----------: | -----------: | ------------: | ------------------- |
# | **fitness**     |  **0.71337** |      0.71135 |  **+0.00202** | 종합 점수: train이 근소 우위 |
# | precision(B)    |     0.921606 | **0.921684** |     −0.000078 | 사실상 동일(0.008%p↓)    |
# | recall(B)       |     0.854939 | **0.855021** |     −0.000082 | 사실상 동일(0.010%p↓)    |
# | **mAP50-95(B)** | **0.690914** |     0.688661 | **+0.002253** | IoU 전구간 평균 AP 소폭↑   |
# | mAP50(B)        |     0.915514 | **0.915540** |     −0.000026 | 사실상 동일              |

# %%
# best_parameters.yaml

# %%
model = YOLO('yolov8n.pt')

model.tune(
    data='./datasets1/data.yaml',
    epochs=20,
    imgsz=640,
    iterations=25,
    val=True
)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs\detect\tune2'
# Tuner:  Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/25 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'cutmix': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune2\tune_scatter_plots.png
# Saved runs\detect\tune2\tune_fitness.png
#
# Tuner: 1/25 iterations complete  (943.07s)
# Tuner: Results saved to runs\detect\tune2
# Tuner: Best fitness=0.78773 observed at iteration 1
# ...

# %%
import yaml  
data_path = './datasets1/data.yaml'
with open("./runs/detect/tune2/best_hyperparameters.yaml", "r", encoding="utf-8") as f:
    hyp_dict = yaml.safe_load(f)
    
model.train(data=data_path, epochs=20, imgsz=640, batch=16, **hyp_dict)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
model.predict('sample.png')
# Out:
# image 1/1 c:\githome\data_anal_DL\sample.png: 448x640 2 Papers, 20.5ms
# Speed: 2.4ms preprocess, 20.5ms inference, 2.8ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Paper', 1: 'Rock', 2: 'Scissors'}
#  obb: None
#  orig_img: array([[[125, 160, 150],
#          [125, 160, 150],
#          [124, 160, 148],
#          ...,
#          [109, 141, 136],
#          [110, 142, 137],
#          [110, 144, 138]],
#
#         [[125, 160, 150],
#          [125, 160, 150],
#          [124, 160, 148],
#          ...,
#          [109, 141, 136],
#          [109, 143, 137],
#          [110, 144, 138]],
#
#         [[126, 160, 150],
#          [126, 160, 150],
#          [125, 159, 148],
#          ...,
#          [107, 141, 135],
#          [108, 142, 136],
#          [109, 143, 137]],
#
#         ...,
#
#         [[ 86, 146, 135],
# ...
